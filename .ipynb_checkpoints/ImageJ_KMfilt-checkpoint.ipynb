# %%
import numpy as np
# from scipy.ndimage import split, merge


class KalmanFilter:
    """
    A class implementing the Kalman Filter for image stacks.
    """

    def __init__(self, percent_var=0.05, gain=0.8):
        """
        Initialize the Kalman Filter with noise variance and gain.

        Args:
            percent_var (float, optional): Acquisition noise variance estimate. Defaults to 0.05.
            gain (float, optional): Bias to be placed on the prediction. Defaults to 0.8.
        """
        self.percent_var = percent_var
        self.gain = gain

    def filter(self, stack):
        """
        Applies the Kalman Filter to a grayscale image stack.

        Args:
            stack (np.ndarray): The input image stack.

        Returns:
            np.ndarray: The filtered image stack.
        """
#         # Check for RGB stack and handle separately
#         if stack.ndim == 3:
#             return self.filter_rgb(stack)

        # Get basic image properties
        width, height = stack.shape[1:]
        dimension = width * height
        stack_size = stack.shape[0]

        # Initialize arrays for calculations
        predicted = stack[0].flatten()
        predicted_var = np.ones(dimension) * self.percent_var
        observed = np.empty_like(predicted)
        kalman = np.empty_like(predicted)
        corrected = np.empty_like(predicted)
        corrected_var = np.empty_like(predicted)

        # Kalman filter loop for each slice
        for i in range(1, stack_size):
            print(f"Kalman filtering slice#{i} of {stack_size}...")
            observed[:] = stack[i].flatten()

            # Calculate Kalman gain and update estimates
            kalman[:] = predicted_var / (predicted_var + self.percent_var)
            corrected[:] = self.gain * predicted + (1.0 - self.gain) * observed + \
                kalman * (observed - predicted)
            corrected_var[:] = predicted_var * (1.0 - kalman)

            # Update predictions for next iteration
            predicted = corrected
            predicted_var = corrected_var
            
            print(f"Predicted-shape = {np.shape(predicted)}")

        return predicted.reshape((stack_size, height, width))

#     def filter_rgb(self, stack):
#         """
#         Applies the Kalman Filter to an RGB image stack.

#         Args:
#             stack (np.ndarray): The input RGB image stack.

#         Returns:
#             np.ndarray: The filtered RGB image stack.
#         """
#         # Split RGB channels
#         red, green, blue = split(stack, axis=2)

#         # Apply filter to each channel
#         filtered_red = self.filter(red)
#         filtered_green = self.filter(green)
#         filtered_blue = self.filter(blue)

#         # Merge filtered channels back to RGB stack
#         return merge((filtered_red, filtered_green, filtered_blue), axis=2)


def main(tif_stk):
    # Input handling and parameter retrieval (replace with your logic)
    percent_var = 0.05
    gain = 0.8

    # Load your image stack (replace with your image loading logic)
    image_stack = tif_stk

    # Create and apply Kalman Filter
    kalman_filter = KalmanFilter(percent_var, gain)
    filtered_stack = kalman_filter.filter(image_stack)

    # Save or display the filtered stack (replace with your logic)
    return filtered_stack


# if __name__ == "__main__":
#     main()

# %%
import tifffile

def read_tif_stack(filename):
    """Reads a .tif image stack into a 3D NumPy array.

    Args:
        filename: The path to the .tif file.

    Returns:
        A 3D NumPy array containing the image stack.
    """

    with tifffile.TiffFile(filename) as tif:
        return tif.asarray()

# %%
import os
import numpy as np

root = "C:\\Users\\svw191\\PythonFiles\\PythonTrial\\LED +APs 240926\\240926_pl100_pc001_LED+APs500microW_ex01\\DATA\\ChanB"
filename = "ChanB_stk.tif"
# stack = read_tif_stack(os.path.join(root,filename))

tif_stk = read_tif_stack(os.path.join(root, filename))
print(np.shape(tif_stk))
# Out:
# (2950, 512, 512)

# %%
tif_stk_filt = main(tif_stk)
# Out:
# Kalman filtering slice#1 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice
of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#698 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#699 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#700 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#701 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#702 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#703 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#704 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#705 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#706 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#707 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#708 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#709 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#710 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#711 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#712 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#713 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#714 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#715 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#716 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#717 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#718 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#719 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#720 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#721 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#722 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#723 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#724 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#725 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#726 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#727 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#728 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#729 of 2950...
# ...
# Kalman filtering slice#2725 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2726 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2727 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2728 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2729 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2730 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2731 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2732 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2733 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2734 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2735 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2736 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2737 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2738 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2739 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2740 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2741 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2742 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2743 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2744 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2745 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2746 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2747 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2748 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2749 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2750 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2751 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2752 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2753 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2754 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2755 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2756 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2757 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2758 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2759 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2760 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2761 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2762 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2763 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2764 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2765 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2766 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2767 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2768 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2769 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2770 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2771 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2772 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2773 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2774 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2775 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2776 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2777 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2778 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2779 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2780 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2781 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2782 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2783 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2784 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2785 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2786 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2787 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2788 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2789 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2790 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2791 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2792 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2793 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2794 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2795 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2796 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2797 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2798 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2799 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2800 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2801 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2802 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2803 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2804 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2805 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2806 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2807 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2808 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2809 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2810 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2811 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2812 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2813 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2814 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2815 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2816 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2817 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2818 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2819 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2820 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2821 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2822 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2823 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2824 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2825 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2826 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2827 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2828 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2829 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2830 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2831 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2832 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2833 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2834 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2835 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2836 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2837 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2838 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2839 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2840 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2841 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2842 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2843 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2844 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2845 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2846 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2847 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2848 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2849 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2850 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2851 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2852 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2853 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2854 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2855 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2856 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2857 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2858 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2859 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2860 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2861 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2862 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2863 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2864 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2865 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2866 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2867 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2868 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2869 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2870 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2871 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2872 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2873 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2874 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2875 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2876 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2877 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2878 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2879 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2880 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2881 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2882 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2883 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2884 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2885 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2886 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2887 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2888 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2889 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2890 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2891 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2892 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2893 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2894 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2895 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2896 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2897 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2898 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2899 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2900 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2901 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2902 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2903 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2904 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2905 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2906 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2907 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2908 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2909 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2910 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2911 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2912 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2913 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2914 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2915 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2916 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2917 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2918 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2919 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2920 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2921 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2922 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2923 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2924 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2925 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2926 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2927 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2928 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2929 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2930 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2931 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2932 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2933 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2934 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2935 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2936 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2937 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2938 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2939 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2940 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2941 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2942 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2943 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2944 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2945 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2946 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2947 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2948 of 2950...
# Predicted-shape = (262144,)
# Kalman filtering slice#2949 of 2950...
# Predicted-shape = (262144,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3432\2548515199.py in <module>
# ----> 1 tif_stk_filt = main(tif_stk)
#
# ~\AppData\Local\Temp\ipykernel_3432\2998675127.py in main(tif_stk)
#      97     # Create and apply Kalman Filter
#      98     kalman_filter = KalmanFilter(percent_var, gain)
# ---> 99     filtered_stack = kalman_filter.filter(image_stack)
#     100
#     101     # Save or display the filtered stack (replace with your logic)
#
# ~\AppData\Local\Temp\ipykernel_3432\2998675127.py in filter(self, stack)
#      63             print(f"Predicted-shape = {np.shape(predicted)}")
#      64
# ---> 65         return predicted.reshape((stack_size, height, width))
#      66
#      67 #     def filter_rgb(self, stack):
#
# ValueError: cannot reshape array of size 262144 into shape (2950,512,512)

# %%
512*512
# Out:
# 262144
